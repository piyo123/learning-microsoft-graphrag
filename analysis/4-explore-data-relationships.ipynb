# %%
import pandas as pd
df = pd.read_parquet("../output/relationships.parquet")

# %%
df.dtypes
# Out:
# id                    object
# human_readable_id      int64
# source                object
# target                object
# description           object
# weight               float64
# combined_degree        int64
# text_unit_ids         object
# dtype: object

# %%
df.shape
# Out:
# (2951, 8)

# %%
df.head()
# Out:
#                                      id  human_readable_id            source  \
# 0  a87153a4-3b89-4804-a99f-548684c4af76                  0   TOKUGAWA IEYASU
# 1  0f00cd98-3bdb-4e48-9429-161e958b4abf                  1      ODA NOBUNAGA
# 2  7db831fa-23b9-4a48-ba3e-0311022ee189                  2   TOKUGAWA IEYASU
# 3  0ca9df1e-98e1-4af0-98cd-29acd2291022                  3  OKEHAZAMA BATTLE
# 4  f059a570-6836-4a00-9da7-afac3ef58d76                  4  OKEHAZAMA BATTLE
#
#             target                                        description  weight  \
# 0    EDO SHOGUNATE  TOKUGAWA IEYASU, the founder of the Edo Shogun...    51.0
# 1  KIYOSU ALLIANCE  Co-founded the Kiyosu Alliance with Ieyasu in ...     9.0
# 2  KIYOSU ALLIANCE  Co-founded the Kiyosu Alliance with Nobunaga i...     9.0
# 3     ODA NOBUNAGA  Nobunaga defeated Imagawa Yoshimoto at Okehaza...     7.0
# 4     IMAGAWA CLAN  The death of Imagawa Yoshimoto at Okehazama re...     6.0
#
# ...

# %%
with pd.option_context(
    "display.max_colwidth", None,
    "display.max_columns", None,
    "display.width", None,
):
    row = df.iloc[0]
    print(row["source"] + " - " + row["target"])
    print("weight=" + str(row["weight"]))
    print(row["description"])
# Out:
# TOKUGAWA IEYASU - EDO SHOGUNATE
# weight=51.0
# TOKUGAWA IEYASU, the founder of the Edo Shogunate, was appointed Shogun and established the Edo bakufu, centralizing political power in Edo. As the first shogun of the Edo Shogunate, he established Tokugawa rule in Japan and laid the foundations of the Edo Shogunate’s governing structure, which guided the country throughout the Edo period. The Edo Shogunate, established by Ieyasu, represents the ruling regime of the Edo period, characterized by centralized authority concentrated in Edo and the enduring Tokugawa governance model that shaped Japan for centuries.

# %% [markdown]
# 上記の日本語訳
#
# > 江戸幕府の創始者である徳川家康は、将軍に任命され、江戸に幕府を開いて政治権力を江戸に集中させました。江戸幕府の初代将軍として、家康は日本に徳川政権を確立し、江戸時代を通じて国を統治することになる江戸幕府の統治体制の基礎を築きました。家康によって樹立された江戸幕府は、江戸を中心とする中央集権的な権力構造を特徴とする江戸時代の支配体制を象徴しており、数世紀にわたって日本を形作った徳川統治モデルの中核を成すものです。

# %%
with pd.option_context(
    "display.max_colwidth", None,
    "display.max_columns", None,
    "display.width", None,
):
    row = df.iloc[4]
    print(row["source"] + " - " + row["target"])
    print("weight=" + str(row["weight"]))
    print(row["description"])
# Out:
# OKEHAZAMA BATTLE - IMAGAWA CLAN
# weight=6.0
# The death of Imagawa Yoshimoto at Okehazama removed Imagawa from power, enabling Nobunaga's expansion

# %% [markdown]
# 上記の日本語訳
#
# > 桶狭間で今川義元が討たれたことにより、今川氏は権力を失い、その結果、信長の勢力拡大が可能となりました。
